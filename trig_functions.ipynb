# %% [markdown]
# # Trigonometry Functions with Numpy and Visualization
#
# Some examples of trigonometry with matplotlib and numpy for learning.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
#import seaborn; seaborn.set()

# %% [markdown]
# The numpy function linspace is pretty handy for plotting.  Here is divides the range 0 to 2pi in 128 equal segments.

# %%
theta = np.linspace(0,2*np.pi,128)

# %%
s = np.sin(theta)
c = np.cos(theta)
t = np.tan(theta)

# %% [markdown]
# Stacking up the scatter plots here let's us put it all on one figure.

# %%
o = plt.plot(theta,s,c='red')
o = plt.plot(theta,c)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# %%
s1 = s
s2 = np.sin(2*theta)

# %%
o = plt.plot(theta,s,c='red')
o = plt.plot(theta,s2)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# %% [markdown]
# ## Now Let's Try a Widget!

# %%
import ipywidgets as widgets

# %%
controller = widgets.IntSlider(
    value=2,
    min=1,
    max=10,
    step=1,
    description='Multiplier:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
display(controller)
# Out:
# IntSlider(value=2, continuous_update=False, description='Multiplier:', max=10, min=1)

# %%
s1 = s
s2 = np.sin(controller.value*theta)
o = plt.plot(theta,s,c='red')
o = plt.plot(theta,s2)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
